# %%
import pandas as pd
ann_app=pd.read_csv('listings.csv')
print(ann_app.head())
print(ann_app.columns)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import pandas as pd
#       2 ann_app=pd.read_csv('listings.csv')
#       3 print(ann_app.head())
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\__init__.py:26
#      24 for _dependency in _hard_dependencies:
#      25     try:
# ---> 26         __import__(_dependency)
#      27     except ImportError as _e:  # pragma: no cover
#      28         _missing_dependencies.append(f"{_dependency}: {_e}")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\__init__.py:127
#     124 from . import _distributor_init
#     126 try:
# --> 127     from numpy.__config__ import show as show_config
#     128 except ImportError as e:
#     129     msg = """Error importing numpy: you should not try to import numpy from
# ...

# %%
comm_voy=pd.read_csv("reviews.csv")
print(comm_voy.head())
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0      222887   836020  2012-01-04       960075        Marjon
# 1      222887  2717072  2012-10-25      2887504        Trevor
# 2      222887  2994458  2012-11-30       405763       William
# 3      222887  3561127  2013-02-17       169773        Daniel
# 4      222887  4230818  2013-04-21      4415172           Sue
#
#                                             comments
# 0  Suzanna's apartment is amazing and it was a tr...
# 1  Great communication  & directions from railway...
# 2  Fabulous location over Bordeaux and manager ve...
# 3  Location is always a must for us and this plac...
# 4  This apartment is delightful.  Thoughtfully an...

# %%
quart_vois=pd.read_csv('neighbourhoods.csv')
print(quart_vois.head())
# Out:
#      neighbourhood_group          neighbourhood
# 0      Ambars-et-Lagrave      Ambars-et-Lagrave
# 1                   Ambs                   Ambs
# 2  Artigues-Prs-Bordeaux  Artigues-Prs-Bordeaux
# 3                Bassens                Bassens
# 4                  Bgles                  Bgles

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import pandas as pd
#       2 calendier=pd.read_csv("calendar.csv")
#       3 print(calendier.head())
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\__init__.py:26
#      24 for _dependency in _hard_dependencies:
#      25     try:
# ---> 26         __import__(_dependency)
#      27     except ImportError as _e:  # pragma: no cover
#      28         _missing_dependencies.append(f"{_dependency}: {_e}")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\__init__.py:127
#     124 from . import _distributor_init
#     126 try:
# --> 127     from numpy.__config__ import show as show_config
#     128 except ImportError as e:
#     129     msg = """Error importing numpy: you should not try to import numpy from
# ...
